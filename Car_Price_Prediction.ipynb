# %%
 # To predict the price of car based on given feature

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df['Owner'] = df['Owner'].replace(3, 2)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
print(df['Seller_Type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 2]

# %%
##check missing values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.039867
# std       2.891554       5.082812       8.644115   38886.883882    0.212302
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    2.000000

# %%
df.drop("Car_Name",axis=1,inplace=True)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [301 rows x 8 columns]

# %%
df['Current Year']=2025

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year
# 0       Manual      0          2025
# 1       Manual      0          2025
# 2       Manual      0          2025
# 3       Manual      0          2025
# 4       Manual      0          2025

# %%
df['Current Year']- df['Year']
# Out:
# 0      11
# 1      12
# 2       8
# 3      14
# 4      11
#        ..
# 296     9
# 297    10
# 298    16
# 299     8
# 300     9
# Length: 301, dtype: int64

# %%
df['no_year']=df['Current Year']- df['Year']

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  no_year
# 0       Manual      0          2025       11
# 1       Manual      0          2025       12
# 2       Manual      0          2025        8
# 3       Manual      0          2025       14
# 4       Manual      0          2025       11

# %%
df.drop(['Year',"Current Year"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no_year
# 0       Manual      0       11
# 1       Manual      0       12
# 2       Manual      0        8
# 3       Manual      0       14
# 4       Manual      0       11

# %%
sns.histplot(x='Selling_Price', data=df)
plt.show()

# %%
sns.scatterplot(x='Selling_Price', y='Present_Price', data=df)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Present_Price'>

# %%
sns.lineplot(x='Selling_Price', y='Present_Price', data=df, ci=None)   # Confidence Interval
plt.show()

# %%
sns.boxplot(x='Kms_Driven', data=df)
plt.show()

# %%
final_dataset=pd.get_dummies(df,drop_first=True,dtype="int")

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0       11                 0
# 1           4.75           9.54       43000      0       12                 1
# 2           7.25           9.85        6900      0        8                 0
# 3           2.85           4.15        5200      0       14                 0
# 4           4.60           6.87       42450      0       11                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
final_dataset.Transmission_Manual.unique()
# Out:
# array([1, 0])

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0       11                 0
# 1           4.75           9.54       43000      0       12                 1
# 2           7.25           9.85        6900      0        8                 0
# 3           2.85           4.15        5200      0       14                 0
# 4           4.60           6.87       42450      0       11                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.096487
# Present_Price                0.878983       1.000000    0.203647 -0.019838
# Kms_Driven                   0.029187       0.203647    1.000000  0.061766
# Owner                       -0.096487      -0.019838    0.061766  1.000000
# no_year                     -0.236141       0.047584    0.524342  0.171232
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.054618
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.057044
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.123854
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.018716
#
#                          no_year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# Kms_Driven              0.524342          0.172515         -0.172874
# Owner                   0.171232         -0.054618          0.057044
# no_year                 1.000000         -0.064315          0.059959
# Fuel_Type_Diesel       -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol        0.059959         -0.979648          1.000000
# Seller_Type_Individual  0.039896         -0.350467          0.358321
# Transmission_Manual    -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.123854            -0.018716
# no_year                               0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
sns.heatmap(final_dataset.corr(),annot=True)
# Out:
# <Axes: >

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  no_year  \
# 0             3.35           5.59       27000      0       11
# 1             4.75           9.54       43000      0       12
# 2             7.25           9.85        6900      0        8
# 3             2.85           4.15        5200      0       14
# 4             4.60           6.87       42450      0       11
# ..             ...            ...         ...    ...      ...
# 296           9.50          11.60       33988      0        9
# 297           4.00           5.90       60000      0       10
# 298           3.35          11.00       87934      0       16
# 299          11.50          12.50        9000      0        8
# 300           5.30           5.90        5464      0        9
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# 1                   1                 0                       0
# 2                   0                 1                       0
# 3                   0                 1                       0
# 4                   1                 0                       0
# ..                ...               ...                     ...
# 296                 1                 0                       0
# 297                 0                 1                       0
# 298                 0                 1                       0
# 299                 1                 0                       0
# 300                 0                 1                       0
#
#      Transmission_Manual
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 296                    1
# 297                    1
# 298                    1
# 299                    1
# 300                    1
#
# [301 rows x 9 columns]

# %%
X=final_dataset.iloc[:, 1:]
y=final_dataset.Selling_Price

# %%
X['Owner'].unique()
# Out:
# array([0, 1, 2])

# %%
X
# Out:
#      Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel  \
# 0             5.59       27000      0       11                 0
# 1             9.54       43000      0       12                 1
# 2             9.85        6900      0        8                 0
# 3             4.15        5200      0       14                 0
# 4             6.87       42450      0       11                 1
# ..             ...         ...    ...      ...               ...
# 296          11.60       33988      0        9                 1
# 297           5.90       60000      0       10                 0
# 298          11.00       87934      0       16                 0
# 299          12.50        9000      0        8                 1
# 300           5.90        5464      0        9                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                   1                       0                    1
# 1                   0                       0                    1
# 2                   1                       0                    1
# 3                   1                       0                    1
# 4                   0                       0                    1
# ..                ...                     ...                  ...
# 296                 0                       0                    1
# 297                 1                       0                    1
# 298                 1                       0                    1
# 299                 0                       0                    1
# 300                 1                       0                    1
#
# [301 rows x 8 columns]

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()

# %%
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([ 6.827 ,  0.4712,  4.62  ,  8.7019, 15.0518,  5.3185,  3.1545,
#         0.4343,  3.8585,  4.674 ,  2.8285,  0.7685,  4.8515,  7.1541,
#         7.7349, 14.9176,  6.6757,  4.009 ,  0.4558,  1.6145,  2.916 ,
#         4.9625,  5.113 ,  9.7841,  0.2018,  0.739 ,  0.34  ,  0.6938,
#         0.4837,  4.0972,  2.6934,  5.969 ,  0.49  ,  7.373 ,  3.3239,
#         1.1702,  5.6765,  5.414 ,  0.2338,  7.9549,  7.8773, 23.1475,
#         4.917 ,  4.429 ,  5.838 , 11.0879,  0.2431,  0.7815,  5.3755,
#         6.772 ,  6.5589,  3.048 ,  5.25  , 24.03  ,  1.1656,  1.1387,
#         0.4785,  2.451 ,  3.5245,  2.5025,  3.8952])

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9569431814083429

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.088360920163934

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_model.pkl', 'wb')

# dump information to that file
pickle.dump(regressor, file)

# %%
file = open('random_forest_regression_model.pkl', 'rb')

# dump information to that file
model = pickle.load(file)

# %%
model
# Out:
# RandomForestRegressor()

# %%
pre = model.predict([[  0.826,6000.000,0.000,13.000,0.000,1.000,1.000,1.000]])

# %%
pre
# Out:
# array([0.4707])

# %%
X_test.iloc[1,:]
# Out:
# Present_Price                0.826
# Kms_Driven                6000.000
# Owner                        0.000
# no_year                     14.000
# Fuel_Type_Diesel             0.000
# Fuel_Type_Petrol             1.000
# Seller_Type_Individual       1.000
# Transmission_Manual          1.000
# Name: 150, dtype: float64

# %%
y_test.iloc[1]
# Out:
# np.float64(0.5)

# %%
0.5-0.4912
# Out:
# 0.008799999999999975

# %%
pre
# Out:
# array([0.4707])

# %%
output = round(pre[0],2)

# %%
output
# Out:
# np.float64(0.47)

# %%
"You Can Sell The Car at {}".format(output)
# Out:
# 'You Can Sell The Car at 0.47'
